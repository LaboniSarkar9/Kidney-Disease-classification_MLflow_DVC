# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d["key1"]
# Out:
# 'val1'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
pip install python-box
# Out:
# Collecting python-box
#   Downloading python_box-7.4.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (8.1 kB)
# Downloading python_box-7.4.1-cp314-cp314-macosx_10_15_universal2.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: python-box
# Successfully installed python-box-7.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
# ensure annotations

def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# '33'

# %%
pip install ensure
# Out:
# Requirement already satisfied: ensure in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.0.4)
# Requirement already satisfied: six>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ensure) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %%
get_product(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_product(x=2,y="3")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x105f6d010> does not match annotation type <class 'int'>
